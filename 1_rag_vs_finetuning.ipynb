# %%
import re
from tqdm.notebook import tqdm
from datasets import load_dataset

# %%
from llama_index import VectorStoreIndex, StorageContext, SimpleDirectoryReader, download_loader, load_index_from_storage
from llama_index.schema import Document
from llama_index.tools import QueryEngineTool, ToolMetadata
from llama_index.agent import ContextRetrieverOpenAIAgent
from llama_index.prompts import PromptTemplate

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import (
    ChatPromptTemplate,
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)
from langchain.schema import HumanMessage, SystemMessage

# %% [markdown]
# ## Define prompt template

# %%
system_template = (
    'Always answer as if you were a customer service agent. '
    'Prefer to use "we" instead of "they"/"them". '
    'Give simple and direct answers.'
)
human_template = "{text}"

chat_prompt = ChatPromptTemplate.from_messages([
    ("system", system_template),
    ("human", human_template),
])

# %%
lamma_index_template = (
    "We have provided context information below. \n"
    "---------------------\n"
    'Always answer as if you were a customer service agent. '
    'Prefer to use "we" instead of "they"/"them". '
    'Give simple and direct answers.'
    "\n---------------------\n"
    "Given this information, please answer the question: {query_str}\n"
)

# %% [markdown]
# ## Define eval data

# %%
eval_data = [
    {
        "original_input": "My robotic arm seems to be misaligned. It's not picking objects accurately. What can I do?",
        "original_output": "It appears that the arm may need recalibration. Please follow the instructions in the user manual to reset the calibration settings. If the problem persists, feel free to contact us again.",
        "input": chat_prompt.format_messages(
            text="My robotic arm is missing the objects it's trying to pick up. Can you please help me?",
        ),
        "default_output": None,
        "fine_tuned_output": None,
        "rag_output": None,
    },
    {
        "original_input": "Our robotic arm's movements seem to be less precise than before.",
        "original_output": "Inconsistent precision might be caused by mechanical wear or environmental factors affecting sensors. Please calibrate the arm and ensure the workspace is clean and free from obstacles. If the problem continues, we can explore additional solutions to improve the arm's precision.",
        "input": chat_prompt.format_messages(
            text="It looks like the arm is losing precision as time goes on. How can I make this better?",
        ),
        "default_output": None,
        "fine_tuned_output": None,
        "rag_output": None,
    },
    {
        "original_input": "After a recent firmware update, the robotic arm is making unexpected movements.",
        "original_output": "Firmware updates can sometimes introduce new behavior. Check the release notes for any changes related to arm movements. If the movements are unintended, roll back to the previous firmware version and report the issue to us for investigation.",
        "input": chat_prompt.format_messages(
            text="My robotic arm has been weird since the last firmware update...",
        ),
        "default_output": None,
        "fine_tuned_output": None,
        "rag_output": None,
    },
    {
        "original_input": "The robotic arm struggles to perform tasks in low light conditions, affecting its operation during nighttime.",
        "original_output": "Low light conditions might impair sensor performance and object detection. Consider using additional lighting or upgrading the sensors for low light capabilities. We'll assist you in optimizing performance in low light conditions.",
        "input": chat_prompt.format_messages(
            text="Sometimes my robotic arm does not work as other times. I'm not sure, but it looks like it works better during the morning/afternoon than during the night. What could be causing this?"
        ),
        "default_output": None,
        "fine_tuned_output": None,
        "rag_output": None,
    },
    {
        "original_input": "The gripping force of the robotic arm's end effector is inconsistent, causing issues with handling fragile objects.",
        "original_output": "Inconsistent gripping force can be due to various factors, such as worn-out gripper components or inaccurate calibration. Check and maintain the gripper's mechanical parts, and recalibrate the gripping force if needed.",
        "input": chat_prompt.format_messages(
            text="The arm has broken a glass that it was trying to pick up. How can I make it grip with less force?"
        ),
        "default_output": None,
        "fine_tuned_output": None,
        "rag_output": None,
    },
    {
        "original_input": "Our robotic arm occasionally jerks suddenly during operation. What could be the problem?",
        "original_output": "Sudden jerky movements can result from motor control issues or improper synchronization. Check the motor control settings and ensure all axes move smoothly. If the issue continues, we'll help you diagnose and fix the problem.",
        "input": chat_prompt.format_messages(
            text="Sometimes my arm makes random movements/twitches - how can I fix this?"
        ),
        "default_output": None,
        "fine_tuned_output": None,
        "rag_output": None,
    },
    {
        "original_input": "-",
        "original_output": "-",
        "input": chat_prompt.format_messages(
            text="How tall is Barack Obama?"
        ),
        "default_output": None,
        "fine_tuned_output": None,
        "rag_output": None,
    },
    {
        "original_input": "-",
        "original_output": "-",
        "input": chat_prompt.format_messages(
            text="Is it possible to order a 3D printed substitution part from you guys?"
        ),
        "default_output": None,
        "fine_tuned_output": None,
        "rag_output": None,
    },
    {
        "original_input": "-",
        "original_output": "-",
        "input": chat_prompt.format_messages(
            text="How can I get substitution parts from you guys?"
        ),
        "default_output": None,
        "fine_tuned_output": None,
        "rag_output": None,
    },
]

# %% [markdown]
# ## Load and process dataset

# %%
dataset = load_dataset("FunDialogues/customer-service-robot-support")

# %%
df = list(dataset.values())[0].to_pandas()

# %%
pattern = re.compile(r'(Customer:|Agent:)')
df['split_dialogue'] = df['dialogue'].apply(lambda x: [substring.strip() for substring in pattern.split(x)[1:]])
df['json_line'] = df['split_dialogue'].apply(
    lambda x: {
        "messages": [
            {"role": "system", "content": system_template},
            {"role": "user", "content": x[1]},
            {"role": "assistant", "content": x[3]},
        ]
    }
)

# %%
df.head()
# Out:
#    index  id                                 description
# 0      0   1               Robotic arm calibration issue  \
# 1      1   2  Overheating problem in production line arm
# 2      2   3           Robotic arm making strange noises
# 3      3   4   Sudden jerky movements in the robotic arm
# 4      4   4      Robotic arm not responding to commands
#
#                                             dialogue
# 0  Customer: My robotic arm seems to be misaligne...  \
# 1  Customer: The robotic arm in our production li...
# 2  Customer: Our robotic arm has been making a we...
# 3  Customer: Our robotic arm occasionally jerks s...
# 4  Customer: My robotic arm is not responding to ...
#
#                                       split_dialogue
# 0  [Customer:, My robotic arm seems to be misalig...  \
# 1  [Customer:, The robotic arm in our production ...
# 2  [Customer:, Our robotic arm has been making a ...
# 3  [Customer:, Our robotic arm occasionally jerks...
# 4  [Customer:, My robotic arm is not responding t...
#
#                                            json_line
# 0  {'messages': [{'role': 'system', 'content': 'A...
# 1  {'messages': [{'role': 'system', 'content': 'A...
# 2  {'messages': [{'role': 'system', 'content': 'A...
# 3  {'messages': [{'role': 'system', 'content': 'A...
# 4  {'messages': [{'role': 'system', 'content': 'A...

# %%
output_file = "llm_training_data.jsonl"
df['json_line'].to_json(output_file, orient='records', lines=True)

# %% [markdown]
# ## Fine tuning

# %%
from openai import OpenAI

# %%
fine_tune = False

# %%
if fine_tune:
    client = OpenAI()
    
    fine_tuning_file = client.files.create(
      file=open(output_file, "rb"),
      purpose="fine-tune"
    )
    
    fine_tuning_job = client.fine_tuning.jobs.create(
      training_file=fine_tuning_file.id, 
      model="gpt-3.5-turbo"
    )

# %%
if fine_tune:
    fine_tuning_result = client.fine_tuning.jobs.retrieve(fine_tuning_job.id)
    fine_tuned_model_name = fine_tuning_result.fine_tuned_model
    if fine_tuning_result.fine_tuned_model:
        print("Fine-tuning process completed.")
        print(f"New model name: {fine_tuned_model_name}")
    else:
        print("Fine-tuning process still ongoing.")
else:
    print("Will use previously existing fine-tuned model.")
    fine_tuned_model_name = "ft:gpt-3.5-turbo-0613:personal::8cdLRUzu"
# Out:
# Will use previously existing fine-tuned model.

# %% [markdown]
# ## RAG Definition

# %%
index = VectorStoreIndex.from_documents([Document(text=doc) for doc in df["dialogue"].to_list()])
index.storage_context.persist(persist_dir="./storage/customer-service-robot-support")
query_engine = index.as_query_engine()

# %%
context_agent = ContextRetrieverOpenAIAgent.from_tools_and_retriever(
    [],
    index.as_retriever(similarity_top_k=3),
    verbose=False,
)

# %% [markdown]
# ## Eval the models

# %%
default_model = ChatOpenAI(temperature=0)

fine_tuned_model = ChatOpenAI(
    temperature=0, model_name=fine_tuned_model_name
)

rag_model = context_agent

# %%
for i, chat in enumerate(eval_data):
    print(f"Working on eval sample #{i}...")
    chat["default_output"] = default_model(
        chat_prompt.format_messages(
            text=chat["input"]
        )
    )
    chat["fine_tuned_output"] = fine_tuned_model(
        chat_prompt.format_messages(
            text=chat["input"]
        )
    )
    chat["rag_output"] = rag_model.chat(
        PromptTemplate(lamma_index_template).format(query_str=chat["input"][1].content)
    ).response
# Out:
# Working on eval sample #0...
# Working on eval sample #1...
# Working on eval sample #2...
# Working on eval sample #3...
# Working on eval sample #4...
# Working on eval sample #5...
# Working on eval sample #6...
# Working on eval sample #7...
# Working on eval sample #8...

# %%
for i, chat in enumerate(eval_data):
    print(f'Chat #{i}')
    print(f'\tOriginal Input:\n\t\t{chat["original_input"]}\n\n')
    print(f'\tOriginal Output:\n\t\t{chat["original_output"]}\n\n')
    print(f'\tNew Input:\n\t\t{chat["input"][1].content}\n\n')
    print(f'\tDefault Output:\n\t\t{chat["default_output"].content}\n\n')
    print(f'\tFine-tuned Output:\n\t\t{chat["fine_tuned_output"].content}\n\n')
    print(f'\tRAG Output:\n\t\t{chat["rag_output"]}')
    
    print('\n\n----------------------------------------------------------------------------------------------------\n\n')
# Out:
# Chat #0
# 	Original Input:
# 		My robotic arm seems to be misaligned. It's not picking objects accurately. What can I do?
#
#
# 	Original Output:
# 		It appears that the arm may need recalibration. Please follow the instructions in the user manual to reset the calibration settings. If the problem persists, feel free to contact us again.
#
#
# 	New Input:
# 		My robotic arm is missing the objects it's trying to pick up. Can you please help me?
#
#
# 	Default Output:
# 		Of course, we're here to help! If your robotic arm is having trouble picking up objects, there are a few things you can try. First, make sure that the arm is properly calibrated and aligned. You may also want to check if there are any obstructions or debris that could be interfering with its operation. If the issue persists, please provide us with more details so we can assist you further.
#
#
# 	Fine-tuned Output:
# 		Object detection issues can occur due to sensor calibration or environmental factors. Check the sensor's calibration and ensure there are no obstructions. If the problem persists, we'll assist you in improving object detection accuracy.
#
#
# 	RAG Output:
# 		It appears that the arm may need recalibration. Please follow the instructions in the user manual to reset the calibration settings. If the problem persists, feel free to contact us again.
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Chat #1
# 	Original Input:
# 		Our robotic arm's movements seem to be less precise than before.
#
#
# 	Original Output:
# 		Inconsistent precision might be caused by mechanical wear or environmental factors affecting sensors. Please calibrate the arm and ensure the workspace is clean and free from obstacles. If the problem continues, we can explore additional solutions to improve the arm's precision.
#
#
# 	New Input:
# 		It looks like the arm is losing precision as time goes on. How can I make this better?
#
#
# 	Default Output:
# 		We apologize for any inconvenience you may be experiencing with the arm's precision. To improve its performance, we recommend checking the arm for any loose or worn-out parts and tightening or replacing them as necessary. Additionally, make sure that the arm is properly calibrated and that the software is up to date. If the issue persists, please contact our customer support team for further assistance.
#
#
# 	Fine-tuned Output:
# 		Precision loss can be due to wear and tear on the arm's components. Regular maintenance and calibration can help maintain precision. If the issue persists, we'll assist you in optimizing the arm's precision.
#
#
# 	RAG Output:
# 		Inconsistent precision might be caused by mechanical wear or environmental factors affecting sensors. Please calibrate the arm and ensure the workspace is clean and free from obstacles. If the problem continues, we can explore additional solutions to improve the arm's precision.
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Chat #2
# 	Original Input:
# 		After a recent firmware update, the robotic arm is making unexpected movements.
#
#
# 	Original Output:
# 		Firmware updates can sometimes introduce new behavior. Check the release notes for any changes related to arm movements. If the movements are unintended, roll back to the previous firmware version and report the issue to us for investigation.
#
#
# 	New Input:
# 		My robotic arm has been weird since the last firmware update...
#
#
# 	Default Output:
# 		I apologize for the inconvenience. Could you please provide more details about the issues you are experiencing with your robotic arm?
#
#
# 	Fine-tuned Output:
# 		Firmware updates can sometimes cause unexpected behavior. Try rolling back to the previous firmware version and see if the arm functions correctly. If not, we'll assist you in diagnosing and resolving the issue.
#
#
# 	RAG Output:
# 		Firmware updates can sometimes introduce new behavior. Check the release notes for any changes related to arm movements. If the movements are unintended, roll back to the previous firmware version and report the issue to us for investigation.
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Chat #3
# 	Original Input:
# 		The robotic arm struggles to perform tasks in low light conditions, affecting its operation during nighttime.
#
#
# 	Original Output:
# 		Low light conditions might impair sensor performance and object detection. Consider using additional lighting or upgrading the sensors for low light capabilities. We'll assist you in optimizing performance in low light conditions.
#
#
# 	New Input:
# 		Sometimes my robotic arm does not work as other times. I'm not sure, but it looks like it works better during the morning/afternoon than during the night. What could be causing this?
#
#
# 	Default Output:
# 		There could be several factors that could affect the performance of your robotic arm. It's possible that there may be variations in power supply or network connectivity during different times of the day, which could impact its functionality. We recommend checking the power source and network connection to ensure they are stable and consistent. If the issue persists, please contact our technical support team for further assistance.
#
#
# 	Fine-tuned Output:
# 		The performance variation might be related to power fluctuations or environmental conditions. Check the power supply and ensure the arm operates within the specified temperature range. If the issue persists, we'll assist you in troubleshooting the arm's performance inconsistency.
#
#
# 	RAG Output:
# 		Low light conditions might impair sensor performance and object detection. Consider using additional lighting or upgrading the sensors for low light capabilities. We'll assist you in optimizing performance in low light conditions.
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Chat #4
# 	Original Input:
# 		The gripping force of the robotic arm's end effector is inconsistent, causing issues with handling fragile objects.
#
#
# 	Original Output:
# 		Inconsistent gripping force can be due to various factors, such as worn-out gripper components or inaccurate calibration. Check and maintain the gripper's mechanical parts, and recalibrate the gripping force if needed.
#
#
# 	New Input:
# 		The arm has broken a glass that it was trying to pick up. How can I make it grip with less force?
#
#
# 	Default Output:
# 		I'm sorry to hear that the arm broke a glass. To make it grip with less force, you can adjust the grip strength settings. Please provide me with the model or type of arm you are using, so I can assist you further.
#
#
# 	Fine-tuned Output:
# 		Gripping force can be adjusted in the gripper's settings. Lower the gripping force to prevent excessive pressure on delicate objects. If you need assistance with the adjustment, we'll guide you through the process.
#
#
# 	RAG Output:
# 		Gripping force adjustments might be necessary for different tasks and object weights. Review the gripping force settings and optimize them for the specific tasks. This will help you make the arm grip with less force and prevent any further damage to delicate objects like glass.
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Chat #5
# 	Original Input:
# 		Our robotic arm occasionally jerks suddenly during operation. What could be the problem?
#
#
# 	Original Output:
# 		Sudden jerky movements can result from motor control issues or improper synchronization. Check the motor control settings and ensure all axes move smoothly. If the issue continues, we'll help you diagnose and fix the problem.
#
#
# 	New Input:
# 		Sometimes my arm makes random movements/twitches - how can I fix this?
#
#
# 	Default Output:
# 		I'm not a doctor, but arm twitches or random movements can have various causes. It's best to consult with a healthcare professional to determine the underlying cause and appropriate treatment options.
#
#
# 	Fine-tuned Output:
# 		Involuntary arm movements can have various causes, such as muscle spasms or nerve issues. Try stretching and massaging the arm to relieve tension. If the problem persists, consult a healthcare professional for further evaluation and guidance.
#
#
# 	RAG Output:
# 		Sudden jerky movements can result from motor control issues or improper synchronization. Check the motor control settings and ensure all axes move smoothly. If the issue continues, we'll help you diagnose and fix the problem.
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Chat #6
# 	Original Input:
# 		-
#
#
# 	Original Output:
# 		-
#
#
# 	New Input:
# 		How tall is Barack Obama?
#
#
# 	Default Output:
# 		Barack Obama is approximately 6 feet 1 inch tall.
#
#
# 	Fine-tuned Output:
# 		Barack Obama's height is approximately 6 feet 1 inch (185 cm).
#
#
# 	RAG Output:
# 		I'm sorry, but I don't have access to real-time information. Is there anything else I can assist you with regarding robotic arms or related topics?
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Chat #7
# 	Original Input:
# 		-
#
#
# 	Original Output:
# 		-
#
#
# 	New Input:
# 		Is it possible to order a 3D printed substitution part from you guys?
#
#
# 	Default Output:
# 		Yes, we offer 3D printed substitution parts. Please provide us with the details of the part you need, and we will assist you further with the ordering process.
#
#
# 	Fine-tuned Output:
# 		Yes, we can assist you with ordering a 3D printed replacement part. Please provide us with the part details and any necessary specifications.
#
#
# 	RAG Output:
# 		I'm sorry, but we do not provide 3D printed substitution parts. However, we can assist you in troubleshooting any issues you may have with your robotic arm or provide guidance on finding suitable replacement parts.
#
#
# ----------------------------------------------------------------------------------------------------
#
#
# Chat #8
# 	Original Input:
# 		-
#
#
# 	Original Output:
# 		-
#
#
# 	New Input:
# 		How can I get substitution parts from you guys?
#
#
# 	Default Output:
# 		Thank you for reaching out to us. To get substitution parts, you can contact our customer service team and provide them with the details of the parts you need. They will assist you further in placing an order or providing information on availability.
#
#
# 	Fine-tuned Output:
# 		You can order substitution parts directly from our website. Simply navigate to the "Parts and Accessories" section and select the parts you need. If you have any difficulties, we'll be happy to assist you.
#
#
# 	RAG Output:
# 		We provide substitution parts for our robotic arms. To get the required parts, please provide us with the specific details of the parts you need, such as part numbers or descriptions. We'll assist you in placing an order for the substitution parts.
#
#
# ----------------------------------------------------------------------------------------------------
